# %%
import numpy as np 
import pandas as pd 
        
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('player_stats.csv')
data
# Out:
#     Rank               Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0      1  Kareem Abdul-Jabbar   32  LAL  147.0    147.0      221  0.665  82
# 1      2        Julius Erving   29  PHI   31.5     31.5      221  0.143  78
# 2      3        George Gervin   27  SAS   19.0     19.0      221  0.086  78
# 3      4           Larry Bird   23  BOS   15.0     15.0      221  0.068  82
# 4     5T       Tiny Archibald   31  BOS    2.0      2.0      221  0.009  80
# ..   ...                  ...  ...  ...    ...      ...      ...    ...  ..
# 674   10          Rudy Gobert   28  UTA    0.0      8.0     1010  0.008  71
# 675   11    Russell Westbrook   32  WAS    0.0      5.0     1010  0.005  65
# 676   12          Ben Simmons   24  PHI    0.0      3.0     1010  0.003  58
# 677  13T         LeBron James   36  LAL    0.0      1.0     1010  0.001  45
# 678  13T        Kawhi Leonard   29  LAC    0.0      1.0     1010  0.001  52
#
#        MP  ...  turnover_percentage  usage_percentage  offensive_win_shares  \
# 0    38.3  ...                 15.7              24.1                   9.5
# 1    36.1  ...                 13.3              30.3                   7.3
# 2    37.6  ...                 10.3              31.7                   9.3
# 3    36.0  ...                 14.0              25.3                   5.6
# 4    35.8  ...                 19.7              17.0                   5.9
# ..    ...  ...                  ...               ...                   ...
# 674  30.8  ...                 13.7              17.0                   6.1
# 675  36.4  ...                 18.0              30.2                   0.5
# 676  32.4  ...                 19.6              20.2                   2.7
# 677  33.4  ...                 15.2              31.9                   3.0
# 678  34.1  ...                  9.2              28.6                   6.4
#
#      defensive_win_shares  win_shares  win_shares_per_48_minutes  \
# 0                     5.3        14.8                      0.227
# 1                     5.2        12.5                      0.213
# 2                     1.3        10.6                      0.173
# 3                     5.6        11.2                      0.182
# 4                     2.9         8.9                      0.148
# ..                    ...         ...                        ...
# 674                   5.2        11.3                      0.248
# 675                   3.2         3.7                      0.075
# 676                   3.3         6.0                      0.153
# 677                   2.6         5.6                      0.179
# 678                   2.4         8.8                      0.238
#
#      offensive_box_plus_minus  defensive_box_plus_minus  box_plus_minus  \
# 0                         4.8                       2.4             7.2
# 1                         5.7                       1.9             7.6
# 2                         5.5                      -1.6             3.9
# 3                         3.0                       1.5             4.5
# 4                         1.4                      -0.3             1.1
# ..                        ...                       ...             ...
# 674                       2.1                       2.8             4.9
# 675                       2.6                       1.1             3.7
# 676                       0.7                       2.2             2.9
# 677                       5.9                       2.3             8.1
# 678                       6.0                       1.3             7.3
#
#      value_over_replacement_player
# 0                              7.3
# 1                              6.8
# 2                              4.4
# 3                              4.8
# 4                              2.3
# ..                             ...
# 674                            3.8
# 675                            3.4
# 676                            2.3
# 677                            3.8
# 678                            4.2
#
# [679 rows x 45 columns]

# %%
data = data.drop(['Rank', 'Player', 'Age', 'Tm', 'First', 'Pts Won', 'WS/48'], axis = 1)

# %% [markdown]
# Training on everything untill 2020 and testing on 2021 data

# %%
train_data = data[data['year']<=2020]
train_data
# Out:
#      Pts Max  Share   G    MP   PTS   TRB  AST  STL  BLK    FG%  ...  \
# 0        221  0.665  82  38.3  24.8  10.8  4.5  1.0  3.4  0.604  ...
# 1        221  0.143  78  36.1  26.9   7.4  4.6  2.2  1.8  0.519  ...
# 2        221  0.086  78  37.6  33.1   5.2  2.6  1.4  1.0  0.528  ...
# 3        221  0.068  82  36.0  21.3  10.4  4.5  1.7  0.6  0.474  ...
# 4        221  0.009  80  35.8  14.1   2.5  8.4  1.3  0.1  0.482  ...
# ..       ...    ...  ..   ...   ...   ...  ...  ...  ...    ...  ...
# 661     1010  0.023  66  37.5  30.0   4.3  8.0  1.1  0.3  0.463  ...
# 662     1010  0.018  73  32.0  19.9   9.7  7.0  1.2  0.6  0.528  ...
# 663     1010  0.017  60  35.2  22.9   7.3  3.5  1.0  0.9  0.453  ...
# 664     1010  0.009  58  33.8  19.9   6.7  6.0  1.8  0.6  0.455  ...
# 665     1010  0.001  66  34.3  23.4   7.0  3.0  1.4  0.9  0.450  ...
#
#      turnover_percentage  usage_percentage  offensive_win_shares  \
# 0                   15.7              24.1                   9.5
# 1                   13.3              30.3                   7.3
# 2                   10.3              31.7                   9.3
# 3                   14.0              25.3                   5.6
# 4                   19.7              17.0                   5.9
# ..                   ...               ...                   ...
# 661                 11.0              30.3                  10.9
# 662                 15.8              26.6                   6.7
# 663                 10.7              28.1                   1.8
# 664                 11.4              25.1                   6.3
# 665                 10.2              28.6                   3.2
#
#      defensive_win_shares win_shares  win_shares_per_48_minutes  \
# 0                     5.3       14.8                      0.227
# 1                     5.2       12.5                      0.213
# 2                     1.3       10.6                      0.173
# 3                     5.6       11.2                      0.182
# 4                     2.9        8.9                      0.148
# ..                    ...        ...                        ...
# 661                   0.7       11.6                      0.225
# 662                   3.1        9.8                      0.202
# 663                   3.6        5.4                      0.123
# 664                   2.7        9.0                      0.221
# 665                   3.7        6.9                      0.146
#
#      offensive_box_plus_minus  defensive_box_plus_minus  box_plus_minus  \
# 0                         4.8                       2.4             7.2
# 1                         5.7                       1.9             7.6
# 2                         5.5                      -1.6             3.9
# 3                         3.0                       1.5             4.5
# 4                         1.4                      -0.3             1.1
# ..                        ...                       ...             ...
# 661                       8.3                      -0.9             7.5
# 662                       5.5                       2.0             7.4
# 663                       1.3                       0.5             1.8
# 664                       4.0                       1.5             5.4
# 665                       3.5                       0.6             4.0
#
#      value_over_replacement_player
# 0                              7.3
# 1                              6.8
# 2                              4.4
# 3                              4.8
# 4                              2.3
# ..                             ...
# 661                            5.9
# 662                            5.5
# 663                            2.0
# 664                            3.7
# 665                            3.4
#
# [666 rows x 38 columns]

# %%
train_data_1980 = train_data.copy()
train_data_2000 =train_data[train_data['year']>=2000]
train_data_2010 =train_data[train_data['year']>=2010]

# %%
sns.pairplot(data=data,
                  x_vars=['Share'])

# %%
data.corr()["Share"].abs().sort_values(ascending = False)
# Out:
# Share                            1.000000
# value_over_replacement_player    0.631312
# WS                               0.619349
# win_shares                       0.618586
# box_plus_minus                   0.603894
# win_shares_per_48_minutes        0.600351
# player_efficiency_rating         0.599861
# offensive_box_plus_minus         0.542630
# offensive_win_shares             0.523072
# PTS                              0.432432
# usage_percentage                 0.366847
# W/L%                             0.350305
# defensive_win_shares             0.335714
# defensive_box_plus_minus         0.328301
# seed                             0.323283
# W                                0.317717
# true_shooting_percentage         0.256370
# MP                               0.213530
# TRB                              0.188887
# defensive_rebound_percentage     0.182973
# assist_percentage                0.158710
# FG%                              0.154296
# total_rebound_percentage         0.148116
# free_throw_attempt_rate          0.139632
# BLK                              0.133683
# AST                              0.130440
# STL                              0.126365
# block_percentage                 0.119449
# year                             0.111664
# G                                0.110165
# steal_percentage                 0.096360
# turnover_percentage              0.092862
# Pts Max                          0.078242
# three_point_attempt_rate         0.072720
# FT%                              0.059078
# 3P%                              0.040934
# offensive_rebound_percentage     0.025482
# Name: Share, dtype: float64

# %%
data2010 = data[data['year']>=2010]

# %%
data2010.corr()["Share"].abs().sort_values(ascending = False)
# Out:
# Share                            1.000000
# value_over_replacement_player    0.709422
# box_plus_minus                   0.672221
# player_efficiency_rating         0.663443
# WS                               0.646824
# win_shares                       0.646824
# win_shares_per_48_minutes        0.625647
# offensive_box_plus_minus         0.605537
# offensive_win_shares             0.561450
# PTS                              0.495728
# usage_percentage                 0.440930
# true_shooting_percentage         0.372929
# W/L%                             0.346526
# defensive_box_plus_minus         0.343460
# defensive_win_shares             0.336248
# seed                             0.328256
# W                                0.309723
# assist_percentage                0.245758
# STL                              0.212124
# MP                               0.203268
# free_throw_attempt_rate          0.202541
# AST                              0.193230
# three_point_attempt_rate         0.188065
# G                                0.176412
# steal_percentage                 0.174273
# FG%                              0.164677
# 3P%                              0.141366
# defensive_rebound_percentage     0.133413
# TRB                              0.132375
# turnover_percentage              0.103809
# total_rebound_percentage         0.100213
# year                             0.046731
# offensive_rebound_percentage     0.030959
# FT%                              0.027915
# Pts Max                          0.026083
# BLK                              0.010097
# block_percentage                 0.004294
# Name: Share, dtype: float64
